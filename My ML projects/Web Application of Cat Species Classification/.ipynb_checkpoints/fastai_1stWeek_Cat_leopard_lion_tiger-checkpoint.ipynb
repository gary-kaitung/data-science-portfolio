# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *
import scipy.io 
import numpy as np
import os

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'fastai-v3/'
# Out:
# Mounted at /content/gdrive

# %%
# assign path directory
path = Path(root_dir + 'Colab Notebooks/CatCategoryDS')
path.ls()
# Out:
# [PosixPath('/content/gdrive/My Drive/Colab Notebooks/CatCategoryDS/train'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/CatCategoryDS/valid'),
#  PosixPath('/content/gdrive/My Drive/Colab Notebooks/CatCategoryDS/models')]

# %%
# store and transform data
data = ImageDataBunch.from_folder(path, ds_tfms=get_transforms(), size=224,bs=20
                                  ).normalize(imagenet_stats)

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['cat', 'leopard', 'lion', 'tiger'], 4, 151, 40)

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
# assign cnn model
learn = create_cnn(data, models.resnet34, metrics=error_rate)
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/vision/learner.py:105: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.torch/models/resnet34-333f7ec4.pth
# 87306240it [00:02, 34756429.65it/s]

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.526418</td>
#       <td>0.287639</td>
#       <td>0.025000</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.858097</td>
#       <td>0.023236</td>
#       <td>0.000000</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.568610</td>
#       <td>0.010677</td>
#       <td>0.000000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.418430</td>
#       <td>0.009859</td>
#       <td>0.000000</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2,max_lr=slice(0.5e-5,1e-5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.108314</td>
#       <td>0.010657</td>
#       <td>0.000000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.113115</td>
#       <td>0.011858</td>
#       <td>0.000000</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %%
learn.load('stage-2');

# %%
interp=ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# # *Below is another method of data scraping from fastai*

# %%
from fastai.vision import *

# %%
folder = 'cat'
file = 'cat.csv'

# %%
folder = 'leopard'
file = 'leopard.csv'

# %%
folder = 'lion'
file = 'lion.csv'

# %%
folder = 'tiger'
file = 'tiger.csv'

# %%
folder = 'cheetah'
file = 'cheetah.csv'

# %%
folder = 'jaguar'
file = 'jaguar.csv'

# %%
path = Path(root_dir+'data/catCategory')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [PosixPath('/content/gdrive/My Drive/data/catCategory/cat'),
#  PosixPath('/content/gdrive/My Drive/data/catCategory/leopard'),
#  PosixPath('/content/gdrive/My Drive/data/catCategory/lion'),
#  PosixPath('/content/gdrive/My Drive/data/catCategory/tiger'),
#  PosixPath('/content/gdrive/My Drive/data/catCategory/models'),
#  PosixPath('/content/gdrive/My Drive/data/catCategory/cheetah'),
#  PosixPath('/content/gdrive/My Drive/data/catCategory/jaguar'),
#  PosixPath('/content/gdrive/My Drive/data/catCategory/cleaned.csv')]

# %%
classes = ['tiger','cat','leopard','lion','jaguar','cheetah']

# %%
download_images(path/folder/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='100' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:06<00:00]
#     </div>
# ...

# %%
dest
# Out:
# PosixPath('/content/gdrive/My Drive/data/catCategory/tiger')

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# tiger
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='93' class='' max='93', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [93/93 00:00<00:00]
#     </div>
# cat
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
# ...

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['cat', 'cheetah', 'jaguar', 'leopard', 'lion', 'tiger']

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['cat', 'cheetah', 'jaguar', 'leopard', 'lion', 'tiger'], 6, 457, 114)

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.701586</td>
#       <td>0.619198</td>
#       <td>0.114035</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.082840</td>
#       <td>0.247401</td>
#       <td>0.078947</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.772590</td>
#       <td>0.210393</td>
#       <td>0.078947</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.616258</td>
#       <td>0.213654</td>
#       <td>0.078947</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.load('stage-1')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (457 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# cat,cat,cat,cat,cat
# Path: /content/gdrive/My Drive/data/catCategory;
#
# Valid: LabelList (114 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# jaguar,cat,leopard,jaguar,jaguar
# Path: /content/gdrive/My Drive/data/catCategory;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
# ...

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f2d1f8d2eb8>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 717, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 713, in _shutdown_workers
#     w.join()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 124, in join
#     res = self._popen.wait(timeout)
#   File "/usr/lib/python3.6/multiprocessing/popen_fork.py", line 50, in wait
#     return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#   File "/usr/lib/python3.6/multiprocessing/popen_fork.py", line 28, in poll
#     pid, sts = os.waitpid(self.pid, flag)
# KeyboardInterrupt:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(3e-5,3e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.228179</td>
#       <td>0.300952</td>
#       <td>0.096491</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.223583</td>
#       <td>0.367306</td>
#       <td>0.096491</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %%
learn.load('stage-2')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (457 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# cat,cat,cat,cat,cat
# Path: /content/gdrive/My Drive/data/catCategory;
#
# Valid: LabelList (114 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# jaguar,cat,leopard,jaguar,jaguar
# Path: /content/gdrive/My Drive/data/catCategory;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
from fastai.widgets import *

# %%
db = (ImageList.from_folder(path)
                   .split_none()
                   .label_from_folder()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics=error_rate)

learn_cln.load('stage-2');

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn_cln)

# %%
ImageCleaner(ds, idxs, path)

# %%
learn.export()

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image(path/'lion'/'00000021.jpg')

# %%
img
# Out:
# Image (3, 296, 500)

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)

# %%
pred_class
# Out:
# Category lion
